# %% [markdown]
# # Deep GRU forecast (runner)
#
# This notebook runs the lightweight GRU trainer (`ml/train_deep_forecast.py`) and prints a 6-hour forecast using `ml/predict_deep_forecast.py`.
#
# You train locally on your Mac (CPU or Apple MPS).

# %%
# One-time install (uncomment if needed)
# !pip -q install torch pandas psycopg2-binary

# %%
# Train (edit lookback/horizon/epochs if you want)
# !python -m ml.train_deep_forecast --lookback 168 --horizon 6 --epochs 20 --device auto --model_out ml/model_registry/eth_gru_h6.pt

# %%
# Predict next 6 hours
# !python -m ml.predict_deep_forecast --model ml/model_registry/eth_gru_h6.pt
